# %% [markdown]
# <a href="https://colab.research.google.com/github/yrodriguezmd/Surgical_instruments/blob/main/Sets/Set_2/notebooks/Set_1_2_merged_Model_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use Model A to generate pseudolabels for Set_2.
#
# Refine Set_2 annotation then fine-tune Model A to result to Model B.

# %%
# !wget https://raw.githubusercontent.com/airctic/icevision/master/install_colab.sh
# !bash install_colab.sh

# %%
exit()

# %%
import icevision

# %%
from icevision.all import *
print('icevision v',icevision.__version__)
print('torch v',torch.__version__)
print('torchvision v',torchvision.__version__)
# Out:
# icevision v 0.10.0a1
# torch v 1.9.0+cu111
# torchvision v 0.10.0+cu111

# %% [markdown]
# Load raw images Set_2.

# %%
! git clone https://github.com/yrodriguezmd/Surgical_instruments.git
# Out:
# Cloning into 'Surgical_instruments'...
# remote: Enumerating objects: 1767, done.
# remote: Counting objects: 100% (283/283), done.
# remote: Compressing objects: 100% (274/274), done.
# remote: Total 1767 (delta 81), reused 7 (delta 7), pack-reused 1484
# Receiving objects: 100% (1767/1767), 52.49 MiB | 20.65 MiB/s, done.
# Resolving deltas: 100% (300/300), done.

# %%
# colab not showing files
# temporary way of uploading:
#from google.colab import drive
#drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls Surgical_instruments/Sets/Set_S/annotated
# Out:
# README.md  test  train	valid

# %%
# visualize
# gdrive
#image_path = Path('gdrive/MyDrive/Surgical_instruments/Set_1.v1i.coco/train')
image_path = Path('Surgical_instruments/Sets/Set_S/annotated')

img_files = get_image_files(image_path)

img = PIL.Image.open(img_files[100]) ##
img = img.convert('RGB')

img.to_thumb(150,150)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF35E04DCD0>

# %%
# using project-specific classes
# 15 classes + background
classes = ['Towel_clip', 'Castroviejo', 'Yankauer', 'Hemostat', 'Army_navy', 'Richardson', 'Potts', 'Iris', 'Bulldog', 'Forceps', 'Scalpel', 'Frazier', 'Needle', 'Weitlaner', 'Mayo_metz']
class_map = ClassMap(classes)
len(class_map)
# Out:
# 16

# %%
imgs_array = [PIL.Image.open(file) for file in img_files]

imgs_array = [image.convert('RGB') for image in imgs_array]

img_size = 384 

valid_tfms = tfms.A.Adapter([*tfms.A.resize_and_pad(img_size), tfms.A.Normalize()])

infer_ds = Dataset.from_images(imgs_array, valid_tfms, class_map = class_map)

# %%
# if with interruption in run, may have to upload model

# %% [markdown]
# Use previously trained Model A.

# %% [markdown]
# Use Set_1_2 merged for this.

# %% [markdown]
# Parse data.

# %%
# !ls Surgical_instruments/Sets/Set_S/annotated
# Out:
# README.md  test  train	valid

# %%
path = Path('Surgical_instruments/Sets/Set_S/annotated') # adjust if use git clone vs gdrive

train_parser = parsers.COCOBBoxParser(
    annotations_filepath = path/'train/Set_1_2_annotations.coco.json',
    img_dir = path/'train'
)

valid_parser = parsers.COCOBBoxParser(
    annotations_filepath = path/'valid/Set_1_2_annotations.coco.json',
    img_dir = path/'valid'
)

# %%
# dataset already split in annotation tool, maintain grouping

whole = SingleSplitSplitter()

train_records, *_ = train_parser.parse(data_splitter = whole)

valid_records, *_ = valid_parser.parse(data_splitter = whole)
# Out:
#   0%|          | 0/212 [00:00<?, ?it/s]
# INFO     - Autofixing records | icevision.parsers.parser:parse:122
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# INFO     - Autofixing records | icevision.parsers.parser:parse:122
#   0%|          | 0/56 [00:00<?, ?it/s]

# %%
# visualize
show_records(train_records[0:3],ncols=3, font_size=30, label_color = '#ffff00')

# %%
show_records(valid_records[0:3],ncols=3, font_size=30, label_color = '#ffff00')

# %% [markdown]
# Transforms and Dataset

# %%
presize = 512
image_size = 384

train_tfms = tfms.A.Adapter([*tfms.A.aug_tfms(size=presize), tfms.A.Normalize()])
valid_tfms = tfms.A.Adapter([*tfms.A.resize_and_pad(size=image_size), tfms.A.Normalize()])

# %%
train_ds = Dataset(train_records, train_tfms)
valid_ds = Dataset(valid_records, valid_tfms)

# %% [markdown]
# Train ModelA - RetinaNet to generate teacher Model B. (Using Set_1_2 merged)

# %%
metrics = [COCOMetric(metric_type=COCOMetricType.bbox)]

model_type = models.mmdet.retinanet ##
backbone = model_type.backbones.resnet50_fpn_1x ##

#model = model_type.model(backbone=backbone(pretrained=True), num_classes=len(classes),)

# %%
from icevision.models import *

checkpoint_path = 'Model_A_ret_mAP34.pth'

checkpoint_and_model = model_from_checkpoint(checkpoint_path)

model = checkpoint_and_model['model']
model.train()

# %%
train_dl = model_type.train_dl(train_ds, batch_size = 16, num_workers = 4,
                               shuffle=True)
valid_dl = model_type.valid_dl(valid_ds, batch_size=16, num_workers = 4,
                               shuffle=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# use wandbd for training monitoring
from fastai.callback.wandb import *

wandb.init(project = 'Surgical_instruments', name = 'Set_1_2_merged_ModelA-B', reinit = True)
# Out:
# wandb: Currently logged in as: maria_rodriguez (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/maria_rodriguez/Surgical_instruments/runs/3cyb75vo" target="_blank">Set_1_2_merged_ModelA-B</a></strong> to <a href="https://wandb.ai/maria_rodriguez/Surgical_instruments" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/maria_rodriguez/Surgical_instruments/runs/3cyb75vo?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
learn = model_type.fastai.learner(dls = [train_dl, valid_dl],
                                  model = model, metrics = metrics,)
                                 # cbs = WandbCallback())

# %%
learn.lr_find()
# Out:
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# SuggestedLRs(valley=4.365158383734524e-05)

# %%
# using Model A to generate Model B, Set_1_2 merged8 ini
learn.fine_tune(30, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>COCOMetric</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.292842</td>
#       <td>1.168046</td>
#       <td>0.039324</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>COCOMetric</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.009935</td>
#       <td>1.072475</td>
#       <td>0.057654</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.950617</td>
#       <td>0.995004</td>
#       <td>0.085579</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.886505</td>
#       <td>0.932257</td>
#       <td>0.136863</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.823381</td>
#       <td>0.887952</td>
#       <td>0.118756</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.762572</td>
#       <td>0.803766</td>
#       <td>0.147884</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.701042</td>
#       <td>0.794429</td>
#       <td>0.183277</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.653644</td>
#       <td>0.772792</td>
#       <td>0.197298</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.612267</td>
#       <td>0.734805</td>
#       <td>0.188988</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.572442</td>
#       <td>0.713618</td>
#       <td>0.239235</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.533500</td>
#       <td>0.670360</td>
#       <td>0.283201</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.504319</td>
#       <td>0.734803</td>
#       <td>0.261417</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.478720</td>
#       <td>0.683196</td>
#       <td>0.262558</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.455449</td>
#       <td>0.641232</td>
#       <td>0.313403</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.432209</td>
#       <td>0.703142</td>
#       <td>0.308928</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.415076</td>
#       <td>0.638726</td>
#       <td>0.316069</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.397459</td>
#       <td>0.665428</td>
#       <td>0.328459</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.379393</td>
#       <td>0.683019</td>
#       <td>0.337363</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.361195</td>
#       <td>0.673600</td>
#       <td>0.330672</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.344967</td>
#       <td>0.680208</td>
#       <td>0.314599</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.329381</td>
#       <td>0.636490</td>
#       <td>0.363570</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.317133</td>
#       <td>0.696912</td>
#       <td>0.314400</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.308548</td>
#       <td>0.663576</td>
#       <td>0.348831</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.299175</td>
#       <td>0.699299</td>
#       <td>0.333571</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.288120</td>
#       <td>0.670899</td>
#       <td>0.345794</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.279734</td>
#       <td>0.667890</td>
#       <td>0.336194</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.273933</td>
#       <td>0.691861</td>
#       <td>0.334960</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.266479</td>
#       <td>0.683888</td>
#       <td>0.344207</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.258436</td>
#       <td>0.671983</td>
#       <td>0.363333</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.251571</td>
#       <td>0.669366</td>
#       <td>0.367232</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.248009</td>
#       <td>0.669114</td>
#       <td>0.367235</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
def plot_metrics(learn, title):
  plt.plot(L(learn.recorder.values).itemgot())
  plt.xlabel('epoch')
  plt.ylabel('mAP (green), Loss (blue, orange)')
  plt.title(title)
  plt.text(0,-0.2, 
       'Legend: mAP(green), train_loss(blue), valid_loss(orange')
  plt.ylim(0,1);

# %%
plot_metrics(learn, 'Set_1_2/ RetinaNet (ModelB), lr 1e-4')

# %%
model_type.show_results(model, valid_ds)
# predictions improving with valid ds
# Out:
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '

# %% [markdown]
# Save model as Model B.

# %%
from icevision.models import *

checkpoint_path = 'Model_B_ret_mAP37.pth'

save_icevision_checkpoint(model, 
                        model_name='mmdet.retinanet', 
                        backbone_name='resnet50_fpn_1x',
                        classes =  train_parser.class_map.get_classes(), 
                        img_size=image_size, 
                        filename=checkpoint_path,
                        meta={'icevision_version': '0.9.1'})

# %%
# temporary
from google.colab import files
files.download(checkpoint_path)

# %% [markdown]
# Store model for later iteration.
#
# (Too big/ inappropriate file for github)
#
# (Store in GDrive)
